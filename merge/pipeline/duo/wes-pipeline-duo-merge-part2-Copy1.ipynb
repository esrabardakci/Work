# %%
import pandas as pd
import re

# %%
data=pd.read_excel('W921_W925.xlsx')

# %%
data
# Out:
#        Unnamed: 0  #Chr      Start        End        Ref  Alt GATK_GT_921  \
# 0               0  chr1    1043224    1043225         CT    -         het
# 1               1  chr1    1387764    1387765         CT    -         hom
# 2               2  chr1    1708856    1708864  TCCTCCTCC    -         hom
# 3               3  chr1    1752908    1752908          -  CCT         het
# 4               4  chr1    1919189    1919197  AGCGGCAGG    -         het
# ...           ...   ...        ...        ...        ...  ...         ...
# 46187       46187  chrX  154227320  154227320          G    T         NaN
# 46188       46188  chrX  154227320  154227320          G    T         NaN
# 46189       46189  chrX  154265124  154265124          G    T         NaN
# 46190       46190  chrX  154265124  154265124          G    T         NaN
# 46191       46191  chrX  154265124  154265124          G    T         NaN
#
#       GATK_GT_925 VarScan GT_921 VarScan GT_925  ... CADD_phred_921  \
# 0             NaN            het            NaN  ...              .
# 1             hom            hom            hom  ...              .
# 2             het            het            het  ...              .
# 3             het            het            het  ...              .
# 4             het            het            het  ...              .
# ...           ...            ...            ...  ...            ...
# 46187         NaN            NaN            het  ...            NaN
# 46188         NaN            NaN            het  ...            NaN
# 46189         NaN            NaN            het  ...            NaN
# 46190         NaN            NaN            het  ...            NaN
# 46191         NaN            NaN            het  ...            NaN
#
#       CADD_phred_925 OMIM_921 OMIM_925  \
# 0                NaN   103320      NaN
# 1                  .   613482   613482
# 2                  .   116951   116951
# 3                  .   611616   611616
# 4                  .        .        .
# ...              ...      ...      ...
# 46187          0.001      NaN        .
# 46188          0.001      NaN        .
# 46189          0.001      NaN   300821
# 46190          0.001      NaN        .
# 46191          0.001      NaN        .
#
#                                           Phenotypes_921  \
# 0      Myasthenic syndrome, congenital, 8, with pre- ...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 46187                                                NaN
# 46188                                                NaN
# 46189                                                NaN
# 46190                                                NaN
# 46191                                                NaN
#
#                                           Phenotypes_925  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 46187                                                NaN
# 46188                                                NaN
# 46189  Colorblindness, deutan, 303800 (3), X-linked; ...
# 46190                                                NaN
# 46191                                                NaN
#
#                                                Orpha_921  \
# 0      590|Congenital myasthenic syndrome|1-9 / 1 000...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 46187                                                NaN
# 46188                                                NaN
# 46189                                                NaN
# 46190                                                NaN
# 46191                                                NaN
#
#                                                Orpha_925 Lab_Frequency_921  \
# 0                                                    NaN             204.0
# 1                                                    NaN             229.0
# 2                                                    NaN             251.0
# 3                                                    NaN             175.0
# 4                                                    NaN             162.0
# ...                                                  ...               ...
# 46187                                                NaN               NaN
# 46188                                                NaN               NaN
# 46189  16|Blue cone monochromatism|1-9 / 100 000|X-li...               NaN
# 46190                                                NaN               NaN
# 46191                                                NaN               NaN
#
#       Lab_Frequency_925
# 0                   NaN
# 1                 228.0
# 2                 250.0
# 3                 174.0
# 4                 161.0
# ...                 ...
# 46187             110.0
# 46188             110.0
# 46189             117.0
# 46190             117.0
# 46191             117.0
#
# [46192 rows x 40 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '#Chr', 'Start', 'End', 'Ref', 'Alt', 'GATK_GT_921',
#        'GATK_GT_925', 'VarScan GT_921', 'VarScan GT_925', 'Ref.Gene_921',
#        'Ref.Gene_925', 'Feature_ID_921', 'Feature_ID_925', 'HGVS_921',
#        'HGVS_925', 'Func.refGene_921', 'Func.refGene_925',
#        'ExonicFunc.refGene_921', 'ExonicFunc.refGene_925', 'avsnp147_921',
#        'avsnp147_925', 'AAChange.refGene_921', 'AAChange.refGene_925',
#        'clinvar: Clinvar_921', 'clinvar: Clinvar_925',
#        'InterVar: InterVar and Evidence_921',
#        'InterVar: InterVar and Evidence_925', 'CADD_raw_921', 'CADD_raw_925',
#        'CADD_phred_921', 'CADD_phred_925', 'OMIM_921', 'OMIM_925',
#        'Phenotypes_921', 'Phenotypes_925', 'Orpha_921', 'Orpha_925',
#        'Lab_Frequency_921', 'Lab_Frequency_925'],
#       dtype='object')

# %%
def merge_specified_columns(df, columns):
    def merge_row(row):
        values = [row[col] for col in columns if pd.notna(row[col]) and row[col] != '']
        if not values:
            return None
        if all(value == values[0] for value in values):
            return values[0]
        return values[0]  # If not identical, return the first non-empty value (or define another rule if needed)
    
    return df.apply(merge_row, axis=1)

# %%
# Specify the columns to merge
columns_to_merge = ['Lab_Frequency_921','Lab_Frequency_925']

# Create the merged column
data['Lab_frequency'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Orpha_921','Orpha_925']

# Create the merged column
data['Orpha_Phenotype'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Phenotypes_921','Phenotypes_925']

# Create the merged column
data['Phenotypes'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['OMIM_921','OMIM_925']

# Create the merged column
data['OMIM_ID'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['CADD_phred_921','CADD_phred_925']

# Create the merged column
data['CADD_phred'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['CADD_raw_921','CADD_raw_925']

# Create the merged column
data['CADD_raw'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['InterVar: InterVar and Evidence_921','InterVar: InterVar and Evidence_925']

# Create the merged column
data['InterVar: InterVar and Evidence'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['clinvar: Clinvar_921', 'clinvar: Clinvar_925']

# Create the merged column
data['Clinvar'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['AAChange.refGene_921','AAChange.refGene_925']

# Create the merged column
data['AAChange.refGene'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['avsnp147_921', 'avsnp147_925']

# Create the merged column
data['avsnp147'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['ExonicFunc.refGene_921', 'ExonicFunc.refGene_925']

# Create the merged column
data['ExonicFunc.refGene'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Func.refGene_921','Func.refGene_925']

# Create the merged column
data['Func.refGene'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['HGVS_921','HGVS_925']

# Create the merged column
data['HGVS'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Feature_ID_921','Feature_ID_925']

# Create the merged column
data['Feature_ID'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Ref.Gene_921','Ref.Gene_925']

# Create the merged column
data['Ref.Gene'] = merge_specified_columns(data, columns_to_merge)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '#Chr', 'Start', 'End', 'Ref', 'Alt', 'GATK_GT_921',
#        'GATK_GT_925', 'VarScan GT_921', 'VarScan GT_925', 'Ref.Gene_921',
#        'Ref.Gene_925', 'Feature_ID_921', 'Feature_ID_925', 'HGVS_921',
#        'HGVS_925', 'Func.refGene_921', 'Func.refGene_925',
#        'ExonicFunc.refGene_921', 'ExonicFunc.refGene_925', 'avsnp147_921',
#        'avsnp147_925', 'AAChange.refGene_921', 'AAChange.refGene_925',
#        'clinvar: Clinvar_921', 'clinvar: Clinvar_925',
#        'InterVar: InterVar and Evidence_921',
#        'InterVar: InterVar and Evidence_925', 'CADD_raw_921', 'CADD_raw_925',
#        'CADD_phred_921', 'CADD_phred_925', 'OMIM_921', 'OMIM_925',
#        'Phenotypes_921', 'Phenotypes_925', 'Orpha_921', 'Orpha_925',
#        'Lab_Frequency_921', 'Lab_Frequency_925', 'Lab_frequency',
#        'Orpha_Phenotype', 'Phenotypes', 'OMIM_ID', 'CADD_phred', 'CADD_raw',
#        'InterVar: InterVar and Evidence', 'Clinvar', 'AAChange.refGene',
#        'avsnp147', 'ExonicFunc.refGene', 'Func.refGene', 'HGVS', 'Feature_ID',
#        'Ref.Gene'],
#       dtype='object')

# %%
data2=data[['#Chr', 'Start', 'End', 'Ref', 'Alt', 'GATK_GT_921','GATK_GT_925', 
            'VarScan GT_921','VarScan GT_925',
            'Ref.Gene','Feature_ID','HGVS','Func.refGene','ExonicFunc.refGene','avsnp147',
           'AAChange.refGene','Clinvar','InterVar: InterVar and Evidence','CADD_phred', 'CADD_raw','OMIM_ID','Phenotypes',
           'Orpha_Phenotype','Lab_frequency']]

# %%
data2
# Out:
#        #Chr      Start        End        Ref  Alt GATK_GT_921 GATK_GT_925  \
# 0      chr1    1043224    1043225         CT    -         het         NaN
# 1      chr1    1387764    1387765         CT    -         hom         hom
# 2      chr1    1708856    1708864  TCCTCCTCC    -         hom         het
# 3      chr1    1752908    1752908          -  CCT         het         het
# 4      chr1    1919189    1919197  AGCGGCAGG    -         het         het
# ...     ...        ...        ...        ...  ...         ...         ...
# 46187  chrX  154227320  154227320          G    T         NaN         NaN
# 46188  chrX  154227320  154227320          G    T         NaN         NaN
# 46189  chrX  154265124  154265124          G    T         NaN         NaN
# 46190  chrX  154265124  154265124          G    T         NaN         NaN
# 46191  chrX  154265124  154265124          G    T         NaN         NaN
#
#       VarScan GT_921 VarScan GT_925 Ref.Gene  ...     avsnp147  \
# 0                het            NaN     AGRN  ...   rs35881187
# 1                hom            hom    CCNL2  ...   rs35654872
# 2                het            het   CDK11A  ...  rs199942750
# 3                het            het     NADK  ...  rs150880809
# 4                het            het   TMEM52  ...  rs575852588
# ...              ...            ...      ...  ...          ...
# 46187            NaN            het  OPN1MW2  ...  rs139163406
# 46188            NaN            het  OPN1MW3  ...  rs139163406
# 46189            NaN            het   OPN1MW  ...            .
# 46190            NaN            het  OPN1MW2  ...            .
# 46191            NaN            het  OPN1MW3  ...            .
#
#                                         AAChange.refGene          Clinvar  \
# 0                                                      .  clinvar: Benign
# 1                                                      .     clinvar: UNK
# 2      CDK11A:NM_001313896:exon9:c.942_950del:p.E322_...     clinvar: UNK
# 3      NADK:NM_001198995:exon10:c.1240_1241insAGG:p.E...     clinvar: UNK
# 4         TMEM52:NM_178545:exon1:c.69_77del:p.L24_L26del     clinvar: UNK
# ...                                                  ...              ...
# 46187  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
# 46188  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
# 46189  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
# 46190  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
# 46191  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
#
#         InterVar: InterVar and Evidence CADD_phred CADD_raw OMIM_ID  \
# 0                      InterVar: Benign          .        .  103320
# 1                      InterVar: Benign          .        .  613482
# 2               InterVar: Likely benign          .        .  116951
# 3                      InterVar: Benign          .        .  611616
# 4                      InterVar: Benign          .        .       .
# ...                                 ...        ...      ...     ...
# 46187                  InterVar: Benign      0.001   -1.873       .
# 46188                  InterVar: Benign      0.001   -1.873       .
# 46189  InterVar: Uncertain significance      0.001   -1.922  300821
# 46190  InterVar: Uncertain significance      0.001   -1.922       .
# 46191  InterVar: Uncertain significance      0.001   -1.922       .
#
#                                               Phenotypes  \
# 0      Myasthenic syndrome, congenital, 8, with pre- ...
# 1                                                   None
# 2                                                   None
# 3                                                   None
# 4                                                   None
# ...                                                  ...
# 46187                                               None
# 46188                                               None
# 46189  Colorblindness, deutan, 303800 (3), X-linked; ...
# 46190                                               None
# 46191                                               None
#
#                                          Orpha_Phenotype Lab_frequency
# 0      590|Congenital myasthenic syndrome|1-9 / 1 000...         204.0
# 1                                                   None         229.0
# 2                                                   None         251.0
# 3                                                   None         175.0
# 4                                                   None         162.0
# ...                                                  ...           ...
# 46187                                               None         110.0
# 46188                                               None         110.0
# 46189  16|Blue cone monochromatism|1-9 / 100 000|X-li...         117.0
# 46190                                               None         117.0
# 46191                                               None         117.0
#
# [46192 rows x 24 columns]

# %%
data2.index+=1

# %%
data2
# Out:
#        #Chr      Start        End        Ref  Alt GATK_GT_921 GATK_GT_925  \
# 1      chr1    1043224    1043225         CT    -         het         NaN
# 2      chr1    1387764    1387765         CT    -         hom         hom
# 3      chr1    1708856    1708864  TCCTCCTCC    -         hom         het
# 4      chr1    1752908    1752908          -  CCT         het         het
# 5      chr1    1919189    1919197  AGCGGCAGG    -         het         het
# ...     ...        ...        ...        ...  ...         ...         ...
# 46188  chrX  154227320  154227320          G    T         NaN         NaN
# 46189  chrX  154227320  154227320          G    T         NaN         NaN
# 46190  chrX  154265124  154265124          G    T         NaN         NaN
# 46191  chrX  154265124  154265124          G    T         NaN         NaN
# 46192  chrX  154265124  154265124          G    T         NaN         NaN
#
#       VarScan GT_921 VarScan GT_925 Ref.Gene  ...     avsnp147  \
# 1                het            NaN     AGRN  ...   rs35881187
# 2                hom            hom    CCNL2  ...   rs35654872
# 3                het            het   CDK11A  ...  rs199942750
# 4                het            het     NADK  ...  rs150880809
# 5                het            het   TMEM52  ...  rs575852588
# ...              ...            ...      ...  ...          ...
# 46188            NaN            het  OPN1MW2  ...  rs139163406
# 46189            NaN            het  OPN1MW3  ...  rs139163406
# 46190            NaN            het   OPN1MW  ...            .
# 46191            NaN            het  OPN1MW2  ...            .
# 46192            NaN            het  OPN1MW3  ...            .
#
#                                         AAChange.refGene          Clinvar  \
# 1                                                      .  clinvar: Benign
# 2                                                      .     clinvar: UNK
# 3      CDK11A:NM_001313896:exon9:c.942_950del:p.E322_...     clinvar: UNK
# 4      NADK:NM_001198995:exon10:c.1240_1241insAGG:p.E...     clinvar: UNK
# 5         TMEM52:NM_178545:exon1:c.69_77del:p.L24_L26del     clinvar: UNK
# ...                                                  ...              ...
# 46188  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
# 46189  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
# 46190  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
# 46191  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
# 46192  OPN1MW:NM_000513:exon3:c.G538T:p.A180S,OPN1MW2...     clinvar: UNK
#
#         InterVar: InterVar and Evidence CADD_phred CADD_raw OMIM_ID  \
# 1                      InterVar: Benign          .        .  103320
# 2                      InterVar: Benign          .        .  613482
# 3               InterVar: Likely benign          .        .  116951
# 4                      InterVar: Benign          .        .  611616
# 5                      InterVar: Benign          .        .       .
# ...                                 ...        ...      ...     ...
# 46188                  InterVar: Benign      0.001   -1.873       .
# 46189                  InterVar: Benign      0.001   -1.873       .
# 46190  InterVar: Uncertain significance      0.001   -1.922  300821
# 46191  InterVar: Uncertain significance      0.001   -1.922       .
# 46192  InterVar: Uncertain significance      0.001   -1.922       .
#
#                                               Phenotypes  \
# 1      Myasthenic syndrome, congenital, 8, with pre- ...
# 2                                                   None
# 3                                                   None
# 4                                                   None
# 5                                                   None
# ...                                                  ...
# 46188                                               None
# 46189                                               None
# 46190  Colorblindness, deutan, 303800 (3), X-linked; ...
# 46191                                               None
# 46192                                               None
#
#                                          Orpha_Phenotype Lab_frequency
# 1      590|Congenital myasthenic syndrome|1-9 / 1 000...         204.0
# 2                                                   None         229.0
# 3                                                   None         251.0
# 4                                                   None         175.0
# 5                                                   None         162.0
# ...                                                  ...           ...
# 46188                                               None         110.0
# 46189                                               None         110.0
# 46190  16|Blue cone monochromatism|1-9 / 100 000|X-li...         117.0
# 46191                                               None         117.0
# 46192                                               None         117.0
#
# [46192 rows x 24 columns]

# %%
data2.to_excel("921-ZehraDidem-İbrahim-Pamukçu-WES-DUO.xlsx")

# %%
data2[data2['Start']==1043224]
# Out:
#        #Chr    Start      End Ref Alt GATK_GT_62438752 GATK_GT_62438828  \
# 35406  chr1  1043224  1043225  CT   -              NaN              hom
#
#       VarScan GT_62438752 VarScan GT_62438828 Ref.Gene  ...    avsnp147  \
# 35406                 NaN                 hom     AGRN  ...  rs35881187
#
#       AAChange.refGene          Clinvar InterVar: InterVar and Evidence  \
# 35406                .  clinvar: Benign                InterVar: Benign
#
#       CADD_phred CADD_raw OMIM_ID  \
# 35406          .        .  103320
#
#                                               Phenotypes  \
# 35406  Myasthenic syndrome, congenital, 8, with pre- ...
#
#                                          Orpha_Phenotype Lab_frequency
# 35406  590|Congenital myasthenic syndrome|1-9 / 1 000...         198.0
#
# [1 rows x 24 columns]

# %%
data2[(data2['GATK_GT_62438828'].notnull()) | (data2['VarScan GT_62438828'].notnull())]
# Out:
#        #Chr      Start        End Ref  Alt GATK_GT_62438752 GATK_GT_62438828  \
# 3      chr1    1629573    1629573   G    -              het              het
# 5      chr1    1752908    1752908   -  CCT              het              hom
# 6      chr1    3627672    3627672   A    -              het              het
# 7      chr1    6470905    6470905   -    G              hom              hom
# 8      chr1    7801093    7801093   -    T              het              hom
# ...     ...        ...        ...  ..  ...              ...              ...
# 41600  chrX  119649918  119649918   G    A              NaN              NaN
# 41601  chrX  135794961  135794961   G    A              NaN              NaN
# 41602  chrX  135794961  135794961   G    A              NaN              NaN
# 41603  chrX  135794961  135794961   G    A              NaN              NaN
# 41604  chrX  141906140  141906140   C    G              NaN              NaN
#
#       VarScan GT_62438752 VarScan GT_62438828 Ref.Gene  ...     avsnp147  \
# 3                     het                 het     MIB2  ...  rs112177324
# 5                     het                 het     NADK  ...  rs150880809
# 6                     het                 het   TPRG1L  ...    rs5772111
# 7                     hom                 hom  PLEKHG5  ...  rs111312565
# 8                     het                 hom     PER3  ...    rs3216852
# ...                   ...                 ...      ...  ...          ...
# 41600                 NaN                 hom  SEPTIN6  ...    rs6603539
# 41601                 NaN                 hom   CT45A5  ...   rs75039634
# 41602                 NaN                 hom   CT45A6  ...   rs75039634
# 41603                 NaN                 hom   CT45A7  ...   rs75039634
# 41604                 NaN                 het   MAGEC1  ...   rs76335605
#
#                                         AAChange.refGene          Clinvar  \
# 3                                                      .     clinvar: UNK
# 5      NADK:NM_001198995:exon10:c.1240_1241insAGG:p.E...     clinvar: UNK
# 6                                                      .     clinvar: UNK
# 7                                                      .  clinvar: Benign
# 8                                                      .     clinvar: UNK
# ...                                                  ...              ...
# 41600                                                  .     clinvar: UNK
# 41601                                                  .     clinvar: UNK
# 41602                                                  .     clinvar: UNK
# 41603                                                  .     clinvar: UNK
# 41604             MAGEC1:NM_005462:exon4:c.C736G:p.L246V     clinvar: UNK
#
#         InterVar: InterVar and Evidence CADD_phred CADD_raw OMIM_ID  \
# 3                      InterVar: Benign          .        .  611141
# 5                      InterVar: Benign          .        .  611616
# 6                      InterVar: Benign          .        .  611460
# 7                      InterVar: Benign          .        .  611101
# 8                      InterVar: Benign          .        .  603427
# ...                                 ...        ...      ...     ...
# 41600                  InterVar: Benign          .        .  300683
# 41601  InterVar: Uncertain significance          .        .  300796
# 41602  InterVar: Uncertain significance          .        .  300797
# 41603  InterVar: Uncertain significance          .        .       .
# 41604                  InterVar: Benign      5.288    0.388  300223
#
#                                               Phenotypes  \
# 3                                                   None
# 5                                                   None
# 6                                                   None
# 7      Spinal muscular atrophy, distal, autosomal rec...
# 8      ?Advanced sleep phase syndrome, familial, 3, 6...
# ...                                                  ...
# 41600                                               None
# 41601                                               None
# 41602                                               None
# 41603                                               None
# 41604                                               None
#
#                                          Orpha_Phenotype Lab_frequency
# 3                                                   None         121.0
# 5                                                   None         169.0
# 6                                                   None         101.0
# 7      369867|Autosomal recessive intermediate Charco...         240.0
# 8      164736|Familial advanced sleep-phase syndrome|...         204.0
# ...                                                  ...           ...
# 41600                                               None          62.0
# 41601                                               None          49.0
# 41602                                               None          49.0
# 41603                                               None          49.0
# 41604                                               None          51.0
#
# [34370 rows x 24 columns]
