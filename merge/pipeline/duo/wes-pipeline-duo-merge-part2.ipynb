# %%
import pandas as pd
import re

# %%
data=pd.read_excel('emir-umut-aydin_temp.xlsx')

# %%
data
# Out:
#        Unnamed: 0  #Chr      Start        End        Ref  Alt  \
# 0               0  chr1    1387764    1387765         CT    -
# 1               1  chr1    1420962    1420964        TCC    -
# 2               2  chr1    1629573    1629573          G    -
# 3               3  chr1    1708856    1708864  TCCTCCTCC    -
# 4               4  chr1    1752908    1752908          -  CCT
# ...           ...   ...        ...        ...        ...  ...
# 41599       41599  chrX  119649918  119649918          G    A
# 41600       41600  chrX  135794961  135794961          G    A
# 41601       41601  chrX  135794961  135794961          G    A
# 41602       41602  chrX  135794961  135794961          G    A
# 41603       41603  chrX  141906140  141906140          C    G
#
#       GATK_GT_62438752 GATK_GT_62438828 VarScan GT_62438752  \
# 0                  hom              NaN                 hom
# 1                  het              NaN                 het
# 2                  het              het                 het
# 3                  het              NaN                 NaN
# 4                  het              hom                 het
# ...                ...              ...                 ...
# 41599              NaN              NaN                 NaN
# 41600              NaN              NaN                 NaN
# 41601              NaN              NaN                 NaN
# 41602              NaN              NaN                 NaN
# 41603              NaN              NaN                 NaN
#
#       VarScan GT_62438828  ... CADD_phred_62438752 CADD_phred_62438828  \
# 0                     NaN  ...                   .                 NaN
# 1                     NaN  ...                   .                 NaN
# 2                     het  ...                   .                   .
# 3                     NaN  ...                   .                 NaN
# 4                     het  ...                   .                   .
# ...                   ...  ...                 ...                 ...
# 41599                 hom  ...                 NaN                   .
# 41600                 hom  ...                 NaN                   .
# 41601                 hom  ...                 NaN                   .
# 41602                 hom  ...                 NaN                   .
# 41603                 het  ...                 NaN               5.288
#
#       OMIM_62438752 OMIM_62438828 Phenotypes_62438752 Phenotypes_62438828  \
# 0            613482           NaN                 NaN                 NaN
# 1                 .           NaN                 NaN                 NaN
# 2            611141        611141                 NaN                 NaN
# 3            116951           NaN                 NaN                 NaN
# 4            611616        611616                 NaN                 NaN
# ...             ...           ...                 ...                 ...
# 41599           NaN        300683                 NaN                 NaN
# 41600           NaN        300796                 NaN                 NaN
# 41601           NaN        300797                 NaN                 NaN
# 41602           NaN             .                 NaN                 NaN
# 41603           NaN        300223                 NaN                 NaN
#
#       Orpha_62438752 Orpha_62438828 Lab_Frequency_62438752  \
# 0                NaN            NaN                  222.0
# 1                NaN            NaN                    8.0
# 2                NaN            NaN                  121.0
# 3                NaN            NaN                  245.0
# 4                NaN            NaN                  169.0
# ...              ...            ...                    ...
# 41599            NaN            NaN                    NaN
# 41600            NaN            NaN                    NaN
# 41601            NaN            NaN                    NaN
# 41602            NaN            NaN                    NaN
# 41603            NaN            NaN                    NaN
#
#       Lab_Frequency_62438828
# 0                        NaN
# 1                        NaN
# 2                      122.0
# 3                        NaN
# 4                      170.0
# ...                      ...
# 41599                   62.0
# 41600                   49.0
# 41601                   49.0
# 41602                   49.0
# 41603                   51.0
#
# [41604 rows x 40 columns]

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '#Chr', 'Start', 'End', 'Ref', 'Alt', 'GATK_GT_62438752',
#        'GATK_GT_62438828', 'VarScan GT_62438752', 'VarScan GT_62438828',
#        'Ref.Gene_62438752', 'Ref.Gene_62438828', 'Feature_ID_62438752',
#        'Feature_ID_62438828', 'HGVS_62438752', 'HGVS_62438828',
#        'Func.refGene_62438752', 'Func.refGene_62438828',
#        'ExonicFunc.refGene_62438752', 'ExonicFunc.refGene_62438828',
#        'avsnp147_62438752', 'avsnp147_62438828', 'AAChange.refGene_62438752',
#        'AAChange.refGene_62438828', 'clinvar: Clinvar_62438752',
#        'clinvar: Clinvar_62438828', 'InterVar: InterVar and Evidence_62438752',
#        'InterVar: InterVar and Evidence_62438828', 'CADD_raw_62438752',
#        'CADD_raw_62438828', 'CADD_phred_62438752', 'CADD_phred_62438828',
#        'OMIM_62438752', 'OMIM_62438828', 'Phenotypes_62438752',
#        'Phenotypes_62438828', 'Orpha_62438752', 'Orpha_62438828',
#        'Lab_Frequency_62438752', 'Lab_Frequency_62438828'],
#       dtype='object')

# %%
def merge_specified_columns(df, columns):
    def merge_row(row):
        values = [row[col] for col in columns if pd.notna(row[col]) and row[col] != '']
        if not values:
            return None
        if all(value == values[0] for value in values):
            return values[0]
        return values[0]  # If not identical, return the first non-empty value (or define another rule if needed)
    
    return df.apply(merge_row, axis=1)

# %%
# Specify the columns to merge
columns_to_merge = ['Lab_Frequency_62438752','Lab_Frequency_62438828']

# Create the merged column
data['Lab_frequency'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Orpha_62438752','Orpha_62438828']

# Create the merged column
data['Orpha_Phenotype'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Phenotypes_62438752','Phenotypes_62438828']

# Create the merged column
data['Phenotypes'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['OMIM_62438752','OMIM_62438828']

# Create the merged column
data['OMIM_ID'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['CADD_phred_62438752','CADD_phred_62438828']

# Create the merged column
data['CADD_phred'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['CADD_raw_62438752','CADD_raw_62438828']

# Create the merged column
data['CADD_raw'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['InterVar: InterVar and Evidence_62438752','InterVar: InterVar and Evidence_62438828']

# Create the merged column
data['InterVar: InterVar and Evidence'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['clinvar: Clinvar_62438752', 'clinvar: Clinvar_62438828']

# Create the merged column
data['Clinvar'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['AAChange.refGene_62438752','AAChange.refGene_62438828']

# Create the merged column
data['AAChange.refGene'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['avsnp147_62438752', 'avsnp147_62438828']

# Create the merged column
data['avsnp147'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['ExonicFunc.refGene_62438752', 'ExonicFunc.refGene_62438828']

# Create the merged column
data['ExonicFunc.refGene'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Func.refGene_62438752','Func.refGene_62438828']

# Create the merged column
data['Func.refGene'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['HGVS_62438752','HGVS_62438828']

# Create the merged column
data['HGVS'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Feature_ID_62438752','Feature_ID_62438828']

# Create the merged column
data['Feature_ID'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Ref.Gene_62438752','Ref.Gene_62438828']

# Create the merged column
data['Ref.Gene'] = merge_specified_columns(data, columns_to_merge)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '#Chr', 'Start', 'End', 'Ref', 'Alt', 'GATK_GT_62438752',
#        'GATK_GT_62438828', 'VarScan GT_62438752', 'VarScan GT_62438828',
#        'Ref.Gene_62438752', 'Ref.Gene_62438828', 'Feature_ID_62438752',
#        'Feature_ID_62438828', 'HGVS_62438752', 'HGVS_62438828',
#        'Func.refGene_62438752', 'Func.refGene_62438828',
#        'ExonicFunc.refGene_62438752', 'ExonicFunc.refGene_62438828',
#        'avsnp147_62438752', 'avsnp147_62438828', 'AAChange.refGene_62438752',
#        'AAChange.refGene_62438828', 'clinvar: Clinvar_62438752',
#        'clinvar: Clinvar_62438828', 'InterVar: InterVar and Evidence_62438752',
#        'InterVar: InterVar and Evidence_62438828', 'CADD_raw_62438752',
#        'CADD_raw_62438828', 'CADD_phred_62438752', 'CADD_phred_62438828',
#        'OMIM_62438752', 'OMIM_62438828', 'Phenotypes_62438752',
#        'Phenotypes_62438828', 'Orpha_62438752', 'Orpha_62438828',
#        'Lab_Frequency_62438752', 'Lab_Frequency_62438828', 'Lab_frequency',
#        'Orpha_Phenotype', 'Phenotypes', 'OMIM_ID', 'CADD_phred', 'CADD_raw',
#        'InterVar: InterVar and Evidence', 'Clinvar', 'AAChange.refGene',
#        'avsnp147', 'ExonicFunc.refGene', 'Func.refGene', 'HGVS', 'Feature_ID',
#        'Ref.Gene'],
#       dtype='object')

# %%
data2=data[['#Chr', 'Start', 'End', 'Ref', 'Alt', 'GATK_GT_62438752','GATK_GT_62438828', 
            'VarScan GT_62438752','VarScan GT_62438828',
            'Ref.Gene','Feature_ID','HGVS','Func.refGene','ExonicFunc.refGene','avsnp147',
           'AAChange.refGene','Clinvar','InterVar: InterVar and Evidence','CADD_phred', 'CADD_raw','OMIM_ID','Phenotypes',
           'Orpha_Phenotype','Lab_frequency']]

# %%
data2
# Out:
#        #Chr      Start        End        Ref  Alt GATK_GT_62438752  \
# 0      chr1    1387764    1387765         CT    -              hom
# 1      chr1    1420962    1420964        TCC    -              het
# 2      chr1    1629573    1629573          G    -              het
# 3      chr1    1708856    1708864  TCCTCCTCC    -              het
# 4      chr1    1752908    1752908          -  CCT              het
# ...     ...        ...        ...        ...  ...              ...
# 41599  chrX  119649918  119649918          G    A              NaN
# 41600  chrX  135794961  135794961          G    A              NaN
# 41601  chrX  135794961  135794961          G    A              NaN
# 41602  chrX  135794961  135794961          G    A              NaN
# 41603  chrX  141906140  141906140          C    G              NaN
#
#       GATK_GT_62438828 VarScan GT_62438752 VarScan GT_62438828 Ref.Gene  ...  \
# 0                  NaN                 hom                 NaN    CCNL2  ...
# 1                  NaN                 het                 NaN  ANKRD65  ...
# 2                  het                 het                 het     MIB2  ...
# 3                  NaN                 NaN                 NaN   CDK11A  ...
# 4                  hom                 het                 het     NADK  ...
# ...                ...                 ...                 ...      ...  ...
# 41599              NaN                 NaN                 hom  SEPTIN6  ...
# 41600              NaN                 NaN                 hom   CT45A5  ...
# 41601              NaN                 NaN                 hom   CT45A6  ...
# 41602              NaN                 NaN                 hom   CT45A7  ...
# 41603              NaN                 NaN                 het   MAGEC1  ...
#
#           avsnp147                                   AAChange.refGene  \
# 0       rs35654872                                                  .
# 1      rs540396555  ANKRD65:NM_001375659:exon1:c.42_44del:p.E15del...
# 2      rs112177324                                                  .
# 3      rs199942750  CDK11A:NM_001313896:exon9:c.942_950del:p.E322_...
# 4      rs150880809  NADK:NM_001198995:exon10:c.1240_1241insAGG:p.E...
# ...            ...                                                ...
# 41599    rs6603539                                                  .
# 41600   rs75039634                                                  .
# 41601   rs75039634                                                  .
# 41602   rs75039634                                                  .
# 41603   rs76335605             MAGEC1:NM_005462:exon4:c.C736G:p.L246V
#
#             Clinvar   InterVar: InterVar and Evidence CADD_phred CADD_raw  \
# 0      clinvar: UNK                  InterVar: Benign          .        .
# 1      clinvar: UNK  InterVar: Uncertain significance          .        .
# 2      clinvar: UNK                  InterVar: Benign          .        .
# 3      clinvar: UNK           InterVar: Likely benign          .        .
# 4      clinvar: UNK                  InterVar: Benign          .        .
# ...             ...                               ...        ...      ...
# 41599  clinvar: UNK                  InterVar: Benign          .        .
# 41600  clinvar: UNK  InterVar: Uncertain significance          .        .
# 41601  clinvar: UNK  InterVar: Uncertain significance          .        .
# 41602  clinvar: UNK  InterVar: Uncertain significance          .        .
# 41603  clinvar: UNK                  InterVar: Benign      5.288    0.388
#
#       OMIM_ID Phenotypes Orpha_Phenotype Lab_frequency
# 0      613482       None            None         222.0
# 1           .       None            None           8.0
# 2      611141       None            None         121.0
# 3      116951       None            None         245.0
# 4      611616       None            None         169.0
# ...       ...        ...             ...           ...
# 41599  300683       None            None          62.0
# 41600  300796       None            None          49.0
# 41601  300797       None            None          49.0
# 41602       .       None            None          49.0
# 41603  300223       None            None          51.0
#
# [41604 rows x 24 columns]

# %%
data2.index+=1

# %%
data2
# Out:
#        #Chr      Start        End        Ref  Alt GATK_GT_62438752  \
# 1      chr1    1387764    1387765         CT    -              hom
# 2      chr1    1420962    1420964        TCC    -              het
# 3      chr1    1629573    1629573          G    -              het
# 4      chr1    1708856    1708864  TCCTCCTCC    -              het
# 5      chr1    1752908    1752908          -  CCT              het
# ...     ...        ...        ...        ...  ...              ...
# 41600  chrX  119649918  119649918          G    A              NaN
# 41601  chrX  135794961  135794961          G    A              NaN
# 41602  chrX  135794961  135794961          G    A              NaN
# 41603  chrX  135794961  135794961          G    A              NaN
# 41604  chrX  141906140  141906140          C    G              NaN
#
#       GATK_GT_62438828 VarScan GT_62438752 VarScan GT_62438828 Ref.Gene  ...  \
# 1                  NaN                 hom                 NaN    CCNL2  ...
# 2                  NaN                 het                 NaN  ANKRD65  ...
# 3                  het                 het                 het     MIB2  ...
# 4                  NaN                 NaN                 NaN   CDK11A  ...
# 5                  hom                 het                 het     NADK  ...
# ...                ...                 ...                 ...      ...  ...
# 41600              NaN                 NaN                 hom  SEPTIN6  ...
# 41601              NaN                 NaN                 hom   CT45A5  ...
# 41602              NaN                 NaN                 hom   CT45A6  ...
# 41603              NaN                 NaN                 hom   CT45A7  ...
# 41604              NaN                 NaN                 het   MAGEC1  ...
#
#           avsnp147                                   AAChange.refGene  \
# 1       rs35654872                                                  .
# 2      rs540396555  ANKRD65:NM_001375659:exon1:c.42_44del:p.E15del...
# 3      rs112177324                                                  .
# 4      rs199942750  CDK11A:NM_001313896:exon9:c.942_950del:p.E322_...
# 5      rs150880809  NADK:NM_001198995:exon10:c.1240_1241insAGG:p.E...
# ...            ...                                                ...
# 41600    rs6603539                                                  .
# 41601   rs75039634                                                  .
# 41602   rs75039634                                                  .
# 41603   rs75039634                                                  .
# 41604   rs76335605             MAGEC1:NM_005462:exon4:c.C736G:p.L246V
#
#             Clinvar   InterVar: InterVar and Evidence CADD_phred CADD_raw  \
# 1      clinvar: UNK                  InterVar: Benign          .        .
# 2      clinvar: UNK  InterVar: Uncertain significance          .        .
# 3      clinvar: UNK                  InterVar: Benign          .        .
# 4      clinvar: UNK           InterVar: Likely benign          .        .
# 5      clinvar: UNK                  InterVar: Benign          .        .
# ...             ...                               ...        ...      ...
# 41600  clinvar: UNK                  InterVar: Benign          .        .
# 41601  clinvar: UNK  InterVar: Uncertain significance          .        .
# 41602  clinvar: UNK  InterVar: Uncertain significance          .        .
# 41603  clinvar: UNK  InterVar: Uncertain significance          .        .
# 41604  clinvar: UNK                  InterVar: Benign      5.288    0.388
#
#       OMIM_ID Phenotypes Orpha_Phenotype Lab_frequency
# 1      613482       None            None         222.0
# 2           .       None            None           8.0
# 3      611141       None            None         121.0
# 4      116951       None            None         245.0
# 5      611616       None            None         169.0
# ...       ...        ...             ...           ...
# 41600  300683       None            None          62.0
# 41601  300796       None            None          49.0
# 41602  300797       None            None          49.0
# 41603       .       None            None          49.0
# 41604  300223       None            None          51.0
#
# [41604 rows x 24 columns]

# %%
data2.to_excel("62438752-62438828_EMIR-UMUT-AYDIN-WES-DUO.xlsx")

# %%
data2[data2['Start']==1043224]
# Out:
#        #Chr    Start      End Ref Alt GATK_GT_62438752 GATK_GT_62438828  \
# 35406  chr1  1043224  1043225  CT   -              NaN              hom
#
#       VarScan GT_62438752 VarScan GT_62438828 Ref.Gene  ...    avsnp147  \
# 35406                 NaN                 hom     AGRN  ...  rs35881187
#
#       AAChange.refGene          Clinvar InterVar: InterVar and Evidence  \
# 35406                .  clinvar: Benign                InterVar: Benign
#
#       CADD_phred CADD_raw OMIM_ID  \
# 35406          .        .  103320
#
#                                               Phenotypes  \
# 35406  Myasthenic syndrome, congenital, 8, with pre- ...
#
#                                          Orpha_Phenotype Lab_frequency
# 35406  590|Congenital myasthenic syndrome|1-9 / 1 000...         198.0
#
# [1 rows x 24 columns]

# %%
data2[(data2['GATK_GT_62438828'].notnull()) | (data2['VarScan GT_62438828'].notnull())]
# Out:
#        #Chr      Start        End Ref  Alt GATK_GT_62438752 GATK_GT_62438828  \
# 3      chr1    1629573    1629573   G    -              het              het
# 5      chr1    1752908    1752908   -  CCT              het              hom
# 6      chr1    3627672    3627672   A    -              het              het
# 7      chr1    6470905    6470905   -    G              hom              hom
# 8      chr1    7801093    7801093   -    T              het              hom
# ...     ...        ...        ...  ..  ...              ...              ...
# 41600  chrX  119649918  119649918   G    A              NaN              NaN
# 41601  chrX  135794961  135794961   G    A              NaN              NaN
# 41602  chrX  135794961  135794961   G    A              NaN              NaN
# 41603  chrX  135794961  135794961   G    A              NaN              NaN
# 41604  chrX  141906140  141906140   C    G              NaN              NaN
#
#       VarScan GT_62438752 VarScan GT_62438828 Ref.Gene  ...     avsnp147  \
# 3                     het                 het     MIB2  ...  rs112177324
# 5                     het                 het     NADK  ...  rs150880809
# 6                     het                 het   TPRG1L  ...    rs5772111
# 7                     hom                 hom  PLEKHG5  ...  rs111312565
# 8                     het                 hom     PER3  ...    rs3216852
# ...                   ...                 ...      ...  ...          ...
# 41600                 NaN                 hom  SEPTIN6  ...    rs6603539
# 41601                 NaN                 hom   CT45A5  ...   rs75039634
# 41602                 NaN                 hom   CT45A6  ...   rs75039634
# 41603                 NaN                 hom   CT45A7  ...   rs75039634
# 41604                 NaN                 het   MAGEC1  ...   rs76335605
#
#                                         AAChange.refGene          Clinvar  \
# 3                                                      .     clinvar: UNK
# 5      NADK:NM_001198995:exon10:c.1240_1241insAGG:p.E...     clinvar: UNK
# 6                                                      .     clinvar: UNK
# 7                                                      .  clinvar: Benign
# 8                                                      .     clinvar: UNK
# ...                                                  ...              ...
# 41600                                                  .     clinvar: UNK
# 41601                                                  .     clinvar: UNK
# 41602                                                  .     clinvar: UNK
# 41603                                                  .     clinvar: UNK
# 41604             MAGEC1:NM_005462:exon4:c.C736G:p.L246V     clinvar: UNK
#
#         InterVar: InterVar and Evidence CADD_phred CADD_raw OMIM_ID  \
# 3                      InterVar: Benign          .        .  611141
# 5                      InterVar: Benign          .        .  611616
# 6                      InterVar: Benign          .        .  611460
# 7                      InterVar: Benign          .        .  611101
# 8                      InterVar: Benign          .        .  603427
# ...                                 ...        ...      ...     ...
# 41600                  InterVar: Benign          .        .  300683
# 41601  InterVar: Uncertain significance          .        .  300796
# 41602  InterVar: Uncertain significance          .        .  300797
# 41603  InterVar: Uncertain significance          .        .       .
# 41604                  InterVar: Benign      5.288    0.388  300223
#
#                                               Phenotypes  \
# 3                                                   None
# 5                                                   None
# 6                                                   None
# 7      Spinal muscular atrophy, distal, autosomal rec...
# 8      ?Advanced sleep phase syndrome, familial, 3, 6...
# ...                                                  ...
# 41600                                               None
# 41601                                               None
# 41602                                               None
# 41603                                               None
# 41604                                               None
#
#                                          Orpha_Phenotype Lab_frequency
# 3                                                   None         121.0
# 5                                                   None         169.0
# 6                                                   None         101.0
# 7      369867|Autosomal recessive intermediate Charco...         240.0
# 8      164736|Familial advanced sleep-phase syndrome|...         204.0
# ...                                                  ...           ...
# 41600                                               None          62.0
# 41601                                               None          49.0
# 41602                                               None          49.0
# 41603                                               None          49.0
# 41604                                               None          51.0
#
# [34370 rows x 24 columns]
