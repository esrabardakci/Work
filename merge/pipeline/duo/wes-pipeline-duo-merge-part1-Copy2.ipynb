# %%
import pandas as pd
import re

# %%
file1_path='W921_S46_results.xlsx'
file2_path='W925_S50_results.xlsx'

# %%
data1=pd.read_excel(file1_path)
data2=pd.read_excel(file2_path)

# %%
string1=re.findall(pattern='\d+(?=_)',string=file1_path)[0]
string2=re.findall(pattern='\d+(?=_)',string=file2_path)[0]

# %%
string2
# Out:
# '925'

# %%
#cols=[a for a in data3.columns if a not in  ['#Chr', 'Start', 'End', 'Ref', 'Alt']]
#a='*'+string3

# %%
#a
# Out:
# '*1087820'

# %%
#data3.columns = ['{}{}'.format(c, str(a) if c in cols else '') for c in data3.columns]

# %%
#data3
# Out:
#        #Chr     Start       End        Ref Alt GATK_GT*1087820  \
# 0      chr1   1043224   1043225         CT   -             het
# 1      chr1   1387764   1387765         CT   -             hom
# 2      chr1   1420962   1420964        TCC   -             het
# 3      chr1   1629573   1629573          G   -             het
# 4      chr1   1708856   1708864  TCCTCCTCC   -             het
# ...     ...       ...       ...        ...  ..             ...
# 35646  chrY  22513968  22513968          T   C             NaN
# 35647  chrY  24047308  24047308          G   A             NaN
# 35648  chrY  24047308  24047308          G   A             NaN
# 35649  chrY  25622823  25622823          C   T             NaN
# 35650  chrY  25622823  25622823          C   T             NaN
#
#       VarScan GT*1087820 Ref.Gene*1087820  \
# 0                    het             AGRN
# 1                    hom            CCNL2
# 2                    het          ANKRD65
# ...

# %%
data_duo=pd.merge(data1,data2, on=['#Chr','Start','End','Ref','Alt'],how='outer',suffixes=('*'+string1,'*'+string2))

# %%
data_duo
# Out:
#        #Chr      Start        End        Ref  Alt GATK_GT*921 VarScan GT*921  \
# 0      chr1    1043224    1043225         CT    -         het            het
# 1      chr1    1387764    1387765         CT    -         hom            hom
# 2      chr1    1708856    1708864  TCCTCCTCC    -         hom            het
# 3      chr1    1752908    1752908          -  CCT         het            het
# 4      chr1    1919189    1919197  AGCGGCAGG    -         het            het
# ...     ...        ...        ...        ...  ...         ...            ...
# 46187  chrX  154227320  154227320          G    T         NaN            NaN
# 46188  chrX  154227320  154227320          G    T         NaN            NaN
# 46189  chrX  154265124  154265124          G    T         NaN            NaN
# 46190  chrX  154265124  154265124          G    T         NaN            NaN
# 46191  chrX  154265124  154265124          G    T         NaN            NaN
#
# ...

# %%
col=sorted(data_duo.columns,key=lambda x: data1.columns.get_loc(x.split('*')[0]))

# %%
col
# Out:
# ['#Chr',
#  'Start',
#  'End',
#  'Ref',
#  'Alt',
#  'GATK_GT*921',
#  'GATK_GT*925',
#  'VarScan GT*921',
#  'VarScan GT*925',
#  'Ref.Gene*921',
#  'Ref.Gene*925',
#  'Feature_ID*921',
#  'Feature_ID*925',
#  'HGVS*921',
#  'HGVS*925',
#  'Func.refGene*921',
#  'Func.refGene*925',
#  'ExonicFunc.refGene*921',
#  'ExonicFunc.refGene*925',
#  'avsnp147*921',
#  'avsnp147*925',
#  'AAChange.refGene*921',
#  'AAChange.refGene*925',
#  'clinvar: Clinvar*921',
#  'clinvar: Clinvar*925',
#  'InterVar: InterVar and Evidence*921',
#  'InterVar: InterVar and Evidence*925',
#  'Freq_gnomAD_genome_ALL*921',
#  'Freq_gnomAD_genome_ALL*925',
#  'Freq_esp6500siv2_all*921',
#  'Freq_esp6500siv2_all*925',
#  'Freq_1000g2015aug_all*921',
#  'Freq_1000g2015aug_all*925',
#  'CADD_raw*921',
#  'CADD_raw*925',
#  'CADD_phred*921',
#  'CADD_phred*925',
#  'SIFT_score*921',
#  'SIFT_score*925',
#  'GERP++_RS*921',
#  'GERP++_RS*925',
#  'phyloP46way_placental*921',
#  'phyloP46way_placental*925',
# ...

# %%
data_duo_update=data_duo[col]

# %%
data_duo_update
# Out:
#        #Chr      Start        End        Ref  Alt GATK_GT*921 GATK_GT*925  \
# 0      chr1    1043224    1043225         CT    -         het         NaN
# 1      chr1    1387764    1387765         CT    -         hom         hom
# 2      chr1    1708856    1708864  TCCTCCTCC    -         hom         het
# 3      chr1    1752908    1752908          -  CCT         het         het
# 4      chr1    1919189    1919197  AGCGGCAGG    -         het         het
# ...     ...        ...        ...        ...  ...         ...         ...
# 46187  chrX  154227320  154227320          G    T         NaN         NaN
# 46188  chrX  154227320  154227320          G    T         NaN         NaN
# 46189  chrX  154265124  154265124          G    T         NaN         NaN
# 46190  chrX  154265124  154265124          G    T         NaN         NaN
# 46191  chrX  154265124  154265124          G    T         NaN         NaN
#
#       VarScan GT*921 VarScan GT*925 Ref.Gene*921  ...  \
# ...

# %%
data_duo_update.columns= data_duo_update.columns.str.replace(r"*","_")
# Out:
# C:\Users\esra.bardakci\AppData\Local\Temp\ipykernel_15608\2995907778.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data_duo_update.columns= data_duo_update.columns.str.replace(r"*","_")

# %%
data_duo_update.columns
# Out:
# Index(['#Chr', 'Start', 'End', 'Ref', 'Alt', 'GATK_GT_921', 'GATK_GT_925',
#        'VarScan GT_921', 'VarScan GT_925', 'Ref.Gene_921', 'Ref.Gene_925',
#        'Feature_ID_921', 'Feature_ID_925', 'HGVS_921', 'HGVS_925',
#        'Func.refGene_921', 'Func.refGene_925', 'ExonicFunc.refGene_921',
#        'ExonicFunc.refGene_925', 'avsnp147_921', 'avsnp147_925',
#        'AAChange.refGene_921', 'AAChange.refGene_925', 'clinvar: Clinvar_921',
#        'clinvar: Clinvar_925', 'InterVar: InterVar and Evidence_921',
#        'InterVar: InterVar and Evidence_925', 'Freq_gnomAD_genome_ALL_921',
#        'Freq_gnomAD_genome_ALL_925', 'Freq_esp6500siv2_all_921',
#        'Freq_esp6500siv2_all_925', 'Freq_1000g2015aug_all_921',
#        'Freq_1000g2015aug_all_925', 'CADD_raw_921', 'CADD_raw_925',
#        'CADD_phred_921', 'CADD_phred_925', 'SIFT_score_921', 'SIFT_score_925',
#        'GERP++_RS_921', 'GERP++_RS_925', 'phyloP46way_placental_921',
# ...

# %%
data_duo_update = data_duo_update.drop(['Freq_gnomAD_genome_ALL_921', 'Freq_gnomAD_genome_ALL_925'
                                        ,'Freq_esp6500siv2_all_921','Freq_esp6500siv2_all_925', 
                                         'Freq_1000g2015aug_all_921', 'Freq_1000g2015aug_all_925',
                                         'Varscan Freq_921', 'Varscan Freq_925', 
                                        'Varscan DP_921','Varscan DP_925',
                                        'SIFT_score_921', 'SIFT_score_925',
                                        'GERP++_RS_921', 'GERP++_RS_925',
                                         'phyloP46way_placental_921','phyloP46way_placental_925', 
                                        'dbscSNV_ADA_SCORE_921', 'dbscSNV_ADA_SCORE_925',
                                         'Interpro_domain_921', 'Interpro_domain_925',
                                          'rmsk_921', 'rmsk_925',
                                          'MetaSVM_score_921', 'MetaSVM_score_925',
                                        'Freq_gnomAD_genome_POPs_921','Freq_gnomAD_genome_POPs_925',
                                        'dbscSNV_RF_SCORE_921','dbscSNV_RF_SCORE_925'], axis=1)

# %%
data_duo_update
# Out:
#        #Chr      Start        End        Ref  Alt GATK_GT_921 GATK_GT_925  \
# 0      chr1    1043224    1043225         CT    -         het         NaN
# 1      chr1    1387764    1387765         CT    -         hom         hom
# 2      chr1    1708856    1708864  TCCTCCTCC    -         hom         het
# 3      chr1    1752908    1752908          -  CCT         het         het
# 4      chr1    1919189    1919197  AGCGGCAGG    -         het         het
# ...     ...        ...        ...        ...  ...         ...         ...
# 46187  chrX  154227320  154227320          G    T         NaN         NaN
# 46188  chrX  154227320  154227320          G    T         NaN         NaN
# 46189  chrX  154265124  154265124          G    T         NaN         NaN
# 46190  chrX  154265124  154265124          G    T         NaN         NaN
# 46191  chrX  154265124  154265124          G    T         NaN         NaN
#
#       VarScan GT_921 VarScan GT_925 Ref.Gene_921  ... CADD_phred_921  \
# ...

# %%
data_duo_update.to_excel("W921_W925.xlsx")
