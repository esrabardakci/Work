# %%
import pandas as pd

# %%
file_path='5513-5515-0871-trio.xlsx'

# %%
data=pd.read_excel(file_path);data
# Out:
#        Chromosome  Position  End Position Cytoband_55135515 Cytoband_0871  \
# 0               1     69453         69453            p36.33           NaN
# 1               1     69511         69511            p36.33           NaN
# 2               1     69552         69552            p36.33           NaN
# 3               1     69569         69569            p36.33           NaN
# 4               1     69849         69849            p36.33           NaN
# ...           ...       ...           ...               ...           ...
# 239208          M     16224         16224               NaN           NaN
# 239209          M     16261         16261               NaN           NaN
# 239210          M     16311         16311               NaN           NaN
# 239211          M     16385         16385               NaN           NaN
# 239212          M     16519         16519               NaN           NaN
#
#        Reference Allele Sample Allele Variation Type_55135515  \
# 0                     G             A                     SNV
# 1                     A             G                     SNV
# 2                     G             C                     SNV
# 3                     T             C                     SNV
# 4                     G             A                     SNV
# ...                 ...           ...                     ...
# 239208                T             C                     NaN
# 239209                C             T                     NaN
# 239210                T             C                     NaN
# 239211                A             G                     NaN
# 239212                T             C                     NaN
#
#        Variation Type_0871 Gene Region_55135515  ... PGMD_55135515 PGMD_0871  \
# 0                      NaN               Exonic  ...           NaN       NaN
# 1                      NaN               Exonic  ...           NaN       NaN
# 2                      NaN               Exonic  ...           NaN       NaN
# 3                      NaN               Exonic  ...           NaN       NaN
# 4                      NaN               Exonic  ...           NaN       NaN
# ...                    ...                  ...  ...           ...       ...
# 239208                 SNV                  NaN  ...           NaN       NaN
# 239209                 SNV                  NaN  ...           NaN       NaN
# 239210                 SNV                  NaN  ...           NaN       NaN
# 239211                 SNV                  NaN  ...           NaN       NaN
# 239212                 SNV                  NaN  ...           NaN       NaN
#
#        COSMIC ID_55135515 COSMIC ID_0871 Cosmic Frequency_55135515  \
# 0                     NaN            NaN                       NaN
# 1                     NaN            NaN                         0
# 2                     NaN            NaN                       NaN
# 3                     NaN            NaN                         0
# 4                     NaN            NaN                       NaN
# ...                   ...            ...                       ...
# 239208                NaN            NaN                       NaN
# 239209                NaN            NaN                       NaN
# 239210                NaN            NaN                       NaN
# 239211                NaN            NaN                       NaN
# 239212                NaN            NaN                       NaN
#
#        Cosmic Frequency_0871 n_55135515 n_0871 Lab_frequency_55135515  \
# 0                        NaN       20.0    NaN               6.079027
# 1                        NaN      113.0    NaN              34.346505
# 2                        NaN       31.0    NaN               9.422492
# 3                        NaN       22.0    NaN               6.686930
# 4                        NaN       27.0    NaN               8.206687
# ...                      ...        ...    ...                    ...
# 239208                   NaN        NaN    7.0                    NaN
# 239209                   NaN        NaN    9.0                    NaN
# 239210                   NaN        NaN   13.0                    NaN
# 239211                   NaN        NaN    2.0                    NaN
# 239212                   NaN        NaN   36.0                    NaN
#
#         Lab_frequency_0871
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 239208            1.772152
# 239209            2.278481
# 239210            3.291139
# 239211            0.506329
# 239212            9.113924
#
# [239213 rows x 114 columns]

# %%
data.columns
# Out:
# Index(['Chromosome', 'Position', 'End Position', 'Cytoband_55135515',
#        'Cytoband_0871', 'Reference Allele', 'Sample Allele',
#        'Variation Type_55135515', 'Variation Type_0871',
#        'Gene Region_55135515',
#        ...
#        'PGMD_55135515', 'PGMD_0871', 'COSMIC ID_55135515', 'COSMIC ID_0871',
#        'Cosmic Frequency_55135515', 'Cosmic Frequency_0871', 'n_55135515',
#        'n_0871', 'Lab_frequency_55135515', 'Lab_frequency_0871'],
#       dtype='object', length=114)

# %%
data = data.drop(['Conservation phyloP p-value_55135515','Conservation phyloP p-value_0871','Regulatory Site_55135515','Regulatory Site_0871',
                  'Regulator_55135515','Regulator_0871','Transcriptional Regulator_55135515','Transcriptional Regulator_0871',
                  'TFBS Enhancer Binding Score_55135515','TFBS Enhancer Binding Score_0871','Enhancer Binding Site_55135515','Enhancer Binding Site_0871',
                 'microRNA Regulator_55135515','microRNA Regulator_0871','Gene Fusion_55135515','Gene Fusion_0871','Fused to_55135515','Fused to_0871',
                 'DGV ID_55135515','DGV ID_0871','Odds Ratio_55135515','Odds Ratio_0871','Association p-value_55135515','Association p-value_0871',
                 'AFC Frequency_55135515','AFC Frequency_0871','CLINVAR ID_55135515','CLINVAR ID_0871','CentoMD_55135515','CentoMD_0871','PGMD_55135515','PGMD_0871',
                 'COSMIC ID_55135515','COSMIC ID_0871','Cosmic Frequency_55135515','Cosmic Frequency_0871'], axis=1)

# %%
data
# Out:
#        Chromosome  Position  End Position Cytoband_55135515 Cytoband_0871  \
# 0               1     69453         69453            p36.33           NaN
# 1               1     69511         69511            p36.33           NaN
# 2               1     69552         69552            p36.33           NaN
# 3               1     69569         69569            p36.33           NaN
# 4               1     69849         69849            p36.33           NaN
# ...           ...       ...           ...               ...           ...
# 239208          M     16224         16224               NaN           NaN
# 239209          M     16261         16261               NaN           NaN
# 239210          M     16311         16311               NaN           NaN
# 239211          M     16385         16385               NaN           NaN
# 239212          M     16519         16519               NaN           NaN
#
#        Reference Allele Sample Allele Variation Type_55135515  \
# 0                     G             A                     SNV
# 1                     A             G                     SNV
# 2                     G             C                     SNV
# 3                     T             C                     SNV
# 4                     G             A                     SNV
# ...                 ...           ...                     ...
# 239208                T             C                     NaN
# 239209                C             T                     NaN
# 239210                T             C                     NaN
# 239211                A             G                     NaN
# 239212                T             C                     NaN
#
#        Variation Type_0871 Gene Region_55135515  ... OMIM Gene_55135515  \
# 0                      NaN               Exonic  ...                NaN
# 1                      NaN               Exonic  ...                NaN
# 2                      NaN               Exonic  ...                NaN
# 3                      NaN               Exonic  ...                NaN
# 4                      NaN               Exonic  ...                NaN
# ...                    ...                  ...  ...                ...
# 239208                 SNV                  NaN  ...                NaN
# 239209                 SNV                  NaN  ...                NaN
# 239210                 SNV                  NaN  ...                NaN
# 239211                 SNV                  NaN  ...                NaN
# 239212                 SNV                  NaN  ...                NaN
#
#        OMIM Gene_0871 OMIM Phenotype_55135515 OMIM Phenotype_0871  \
# 0                 NaN                     NaN                 NaN
# 1                 NaN                     NaN                 NaN
# 2                 NaN                     NaN                 NaN
# 3                 NaN                     NaN                 NaN
# 4                 NaN                     NaN                 NaN
# ...               ...                     ...                 ...
# 239208            NaN                     NaN                 NaN
# 239209            NaN                     NaN                 NaN
# 239210            NaN                     NaN                 NaN
# 239211            NaN                     NaN                 NaN
# 239212            NaN                     NaN                 NaN
#
#        OMIM ID_55135515 OMIM ID_0871 n_55135515 n_0871 Lab_frequency_55135515  \
# 0                   NaN          NaN       20.0    NaN               6.079027
# 1                   NaN          NaN      113.0    NaN              34.346505
# 2                   NaN          NaN       31.0    NaN               9.422492
# 3                   NaN          NaN       22.0    NaN               6.686930
# 4                   NaN          NaN       27.0    NaN               8.206687
# ...                 ...          ...        ...    ...                    ...
# 239208              NaN          NaN        NaN    7.0                    NaN
# 239209              NaN          NaN        NaN    9.0                    NaN
# 239210              NaN          NaN        NaN   13.0                    NaN
# 239211              NaN          NaN        NaN    2.0                    NaN
# 239212              NaN          NaN        NaN   36.0                    NaN
#
#         Lab_frequency_0871
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 239208            1.772152
# 239209            2.278481
# 239210            3.291139
# 239211            0.506329
# 239212            9.113924
#
# [239213 rows x 78 columns]

# %%
data.columns
# Out:
# Index(['Chromosome', 'Position', 'End Position', 'Cytoband_55135515',
#        'Cytoband_0871', 'Reference Allele', 'Sample Allele',
#        'Variation Type_55135515', 'Variation Type_0871',
#        'Gene Region_55135515', 'Gene Region_0871', 'Gene Symbol_55135515',
#        'Gene Symbol_0871', 'Transcript ID_55135515', 'Transcript ID_0871',
#        'Transcript Variant_55135515', 'Transcript Variant_0871',
#        'Protein Variant_55135515', 'Protein Variant_0871',
#        'Variant Findings_55135515', 'Variant Findings_0871',
#        'Case Samples_55135515', 'Case Samples_0871',
#        'Case Samples With Variant_55135515', 'Case Samples With Variant_0871',
#        'Inferred Activity_5513', 'Inferred Activity_5515',
#        'Inferred Activity_0871', 'Genotype_5513', 'Genotype_5515',
#        'Genotype_0871', 'Sample Genotype Quality_55135515',
#        'Sample Genotype Quality_0871', 'Compound Heterozygous_5513',
#        'Compound Heterozygous_5515', 'Compound Heterozygous_0871',
#        'Call Quality_5513', 'Call Quality_5515', 'Call Quality_0871',
#        'Read Depth_5513', 'Read Depth_5515', 'Read Depth_0871',
#        'Allele Fraction_5513', 'Allele Fraction_5515', 'Allele Fraction_0871',
#        'Copy Number_5513', 'Copy Number_5515', 'Copy Number_0871',
#        'Sample Upstream Filtering_55135515', 'Sample Upstream Filtering_0871',
#        'Translation Impact_55135515', 'Translation Impact_0871',
#        'Classification_55135515', 'Classification_0871',
#        'SIFT Function Prediction_55135515', 'SIFT Function Prediction_0871',
#        'SIFT Score_55135515', 'SIFT Score_0871',
#        'PolyPhen-2 Function Prediction_55135515',
#        'PolyPhen-2 Function Prediction_0871', 'CADD Score_55135515',
#        'CADD Score_0871', 'dbSNP ID_55135515', 'dbSNP ID_0871',
#        'gnomAD Frequency_55135515', 'gnomAD Frequency_0871', 'HGMD_55135515',
#        'HGMD_0871', 'OMIM Gene_55135515', 'OMIM Gene_0871',
#        'OMIM Phenotype_55135515', 'OMIM Phenotype_0871', 'OMIM ID_55135515',
#        'OMIM ID_0871', 'n_55135515', 'n_0871', 'Lab_frequency_55135515',
#        'Lab_frequency_0871'],
#       dtype='object')

# %%
data=data.drop(['SIFT Function Prediction_55135515','SIFT Function Prediction_0871','PolyPhen-2 Function Prediction_55135515','PolyPhen-2 Function Prediction_0871',
               'gnomAD Frequency_55135515','gnomAD Frequency_0871'],axis=1)

# %%
data.columns
# Out:
# Index(['Chromosome', 'Position', 'End Position', 'Cytoband_55135515',
#        'Cytoband_0871', 'Reference Allele', 'Sample Allele',
#        'Variation Type_55135515', 'Variation Type_0871',
#        'Gene Region_55135515', 'Gene Region_0871', 'Gene Symbol_55135515',
#        'Gene Symbol_0871', 'Transcript ID_55135515', 'Transcript ID_0871',
#        'Transcript Variant_55135515', 'Transcript Variant_0871',
#        'Protein Variant_55135515', 'Protein Variant_0871',
#        'Variant Findings_55135515', 'Variant Findings_0871',
#        'Case Samples_55135515', 'Case Samples_0871',
#        'Case Samples With Variant_55135515', 'Case Samples With Variant_0871',
#        'Inferred Activity_5513', 'Inferred Activity_5515',
#        'Inferred Activity_0871', 'Genotype_5513', 'Genotype_5515',
#        'Genotype_0871', 'Sample Genotype Quality_55135515',
#        'Sample Genotype Quality_0871', 'Compound Heterozygous_5513',
#        'Compound Heterozygous_5515', 'Compound Heterozygous_0871',
#        'Call Quality_5513', 'Call Quality_5515', 'Call Quality_0871',
#        'Read Depth_5513', 'Read Depth_5515', 'Read Depth_0871',
#        'Allele Fraction_5513', 'Allele Fraction_5515', 'Allele Fraction_0871',
#        'Copy Number_5513', 'Copy Number_5515', 'Copy Number_0871',
#        'Sample Upstream Filtering_55135515', 'Sample Upstream Filtering_0871',
#        'Translation Impact_55135515', 'Translation Impact_0871',
#        'Classification_55135515', 'Classification_0871', 'SIFT Score_55135515',
#        'SIFT Score_0871', 'CADD Score_55135515', 'CADD Score_0871',
#        'dbSNP ID_55135515', 'dbSNP ID_0871', 'HGMD_55135515', 'HGMD_0871',
#        'OMIM Gene_55135515', 'OMIM Gene_0871', 'OMIM Phenotype_55135515',
#        'OMIM Phenotype_0871', 'OMIM ID_55135515', 'OMIM ID_0871', 'n_55135515',
#        'n_0871', 'Lab_frequency_55135515', 'Lab_frequency_0871'],
#       dtype='object')

# %%
def merge_specified_columns(df, columns):
    def merge_row(row):
        values = [row[col] for col in columns if pd.notna(row[col]) and row[col] != '']
        if not values:
            return None
        if all(value == values[0] for value in values):
            return values[0]
        return values[0]  # If not identical, return the first non-empty value (or define another rule if needed)
    
    return df.apply(merge_row, axis=1)

# %%
# Specify the columns to merge
columns_to_merge = [ 'Lab_frequency_55135515', 'Lab_frequency_0871']

# Create the merged column
data['Lab_frequency'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['n_55135515', 'n_0871']

# Create the merged column
data['n'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['OMIM ID_55135515', 'OMIM ID_0871']

# Create the merged column
data['OMIM ID'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['OMIM Phenotype_55135515', 'OMIM Phenotype_0871']

# Create the merged column
data['OMIM Phenotype'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['OMIM Gene_55135515', 'OMIM Gene_0871']

# Create the merged column
data['OMIM Gene'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['HGMD_55135515','HGMD_0871']

# Create the merged column
data['HGMD'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['dbSNP ID_55135515','dbSNP ID_0871']

# Create the merged column
data['dbSNP ID'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['CADD Score_55135515','CADD Score_0871']

# Create the merged column
data['CADD Score'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['SIFT Score_55135515','SIFT Score_0871']

# Create the merged column
data['SIFT Score'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Classification_55135515','Classification_0871']

# Create the merged column
data['Classification'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Translation Impact_55135515', 'Translation Impact_0871']

# Create the merged column
data['Translation Impact'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Sample Upstream Filtering_55135515', 'Sample Upstream Filtering_0871']

# Create the merged column
data['Sample Upstream Filtering'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Copy Number_5513', 'Copy Number_5515','Copy Number_0871',]

# Create the merged column
data['Copy Number'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Compound Heterozygous_5513','Compound Heterozygous_5515','Compound Heterozygous_0871']

# Create the merged column
data['Compound Heterozygous'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Inferred Activity_5513', 'Inferred Activity_5515','Inferred Activity_0871']

# Create the merged column
data['Inferred Activity'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Case Samples With Variant_55135515','Case Samples With Variant_0871']

# Create the merged column
data['Case Samples With Variant'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Variant Findings_55135515','Variant Findings_0871']

# Create the merged column
data['Variant Findings'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Protein Variant_55135515','Protein Variant_0871']

# Create the merged column
data['Protein Variant'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Transcript Variant_55135515','Transcript Variant_0871']

# Create the merged column
data['Transcript Variant'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Transcript ID_55135515','Transcript ID_0871']

# Create the merged column
data['Transcript ID'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Gene Symbol_55135515','Gene Symbol_0871']

# Create the merged column
data['Gene Symbol'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Gene Region_55135515','Gene Region_0871']

# Create the merged column
data['Gene Region'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Variation Type_55135515','Variation Type_0871']

# Create the merged column
data['Variation Type'] = merge_specified_columns(data, columns_to_merge)

# %%
# Specify the columns to merge
columns_to_merge = ['Cytoband_55135515','Cytoband_0871']

# Create the merged column
data['Cytoband'] = merge_specified_columns(data, columns_to_merge)

# %%
data.columns
# Out:
# Index(['Chromosome', 'Position', 'End Position', 'Cytoband_55135515',
#        'Cytoband_0871', 'Reference Allele', 'Sample Allele',
#        'Variation Type_55135515', 'Variation Type_0871',
#        'Gene Region_55135515', 'Gene Region_0871', 'Gene Symbol_55135515',
#        'Gene Symbol_0871', 'Transcript ID_55135515', 'Transcript ID_0871',
#        'Transcript Variant_55135515', 'Transcript Variant_0871',
#        'Protein Variant_55135515', 'Protein Variant_0871',
#        'Variant Findings_55135515', 'Variant Findings_0871',
#        'Case Samples_55135515', 'Case Samples_0871',
#        'Case Samples With Variant_55135515', 'Case Samples With Variant_0871',
#        'Inferred Activity_5513', 'Inferred Activity_5515',
#        'Inferred Activity_0871', 'Genotype_5513', 'Genotype_5515',
#        'Genotype_0871', 'Sample Genotype Quality_55135515',
#        'Sample Genotype Quality_0871', 'Compound Heterozygous_5513',
#        'Compound Heterozygous_5515', 'Compound Heterozygous_0871',
#        'Call Quality_5513', 'Call Quality_5515', 'Call Quality_0871',
#        'Read Depth_5513', 'Read Depth_5515', 'Read Depth_0871',
#        'Allele Fraction_5513', 'Allele Fraction_5515', 'Allele Fraction_0871',
#        'Copy Number_5513', 'Copy Number_5515', 'Copy Number_0871',
#        'Sample Upstream Filtering_55135515', 'Sample Upstream Filtering_0871',
#        'Translation Impact_55135515', 'Translation Impact_0871',
#        'Classification_55135515', 'Classification_0871', 'SIFT Score_55135515',
#        'SIFT Score_0871', 'CADD Score_55135515', 'CADD Score_0871',
#        'dbSNP ID_55135515', 'dbSNP ID_0871', 'HGMD_55135515', 'HGMD_0871',
#        'OMIM Gene_55135515', 'OMIM Gene_0871', 'OMIM Phenotype_55135515',
#        'OMIM Phenotype_0871', 'OMIM ID_55135515', 'OMIM ID_0871', 'n_55135515',
#        'n_0871', 'Lab_frequency_55135515', 'Lab_frequency_0871',
#        'Lab_frequency', 'n', 'OMIM ID', 'OMIM Phenotype', 'OMIM Gene', 'HGMD',
#        'dbSNP ID', 'CADD Score', 'SIFT Score', 'Classification',
#        'Translation Impact', 'Sample Upstream Filtering', 'Variant Findings',
#        'Protein Variant', 'Transcript Variant', 'Transcript ID', 'Gene Symbol',
#        'Gene Region', 'Variation Type', 'Cytoband', 'Copy Number',
#        'Compound Heterozygous', 'Inferred Activity',
#        'Case Samples With Variant'],
#       dtype='object')

# %%
data2=data[['Chromosome','Position','End Position','Cytoband','Reference Allele', 'Sample Allele','Variation Type','Gene Region',
           'Gene Symbol','Transcript ID','Transcript Variant','Protein Variant','Variant Findings','Case Samples_55135515','Case Samples_0871','Case Samples With Variant',
           'Inferred Activity','Genotype_5513','Genotype_5515','Genotype_0871','Sample Genotype Quality_55135515','Sample Genotype Quality_0871','Compound Heterozygous','Call Quality_5513','Call Quality_5515','Call Quality_0871',
            'Read Depth_5513','Read Depth_5515','Read Depth_0871','Allele Fraction_5513','Allele Fraction_5515','Allele Fraction_0871',
           'Copy Number','Sample Upstream Filtering','Translation Impact','Classification','SIFT Score','CADD Score','dbSNP ID','HGMD',
           'OMIM Gene','OMIM Phenotype','OMIM ID','n','Lab_frequency']]

# %%
data2
# Out:
#        Chromosome  Position  End Position Cytoband Reference Allele  \
# 0               1     69453         69453   p36.33                G
# 1               1     69511         69511   p36.33                A
# 2               1     69552         69552   p36.33                G
# 3               1     69569         69569   p36.33                T
# 4               1     69849         69849   p36.33                G
# ...           ...       ...           ...      ...              ...
# 239208          M     16224         16224     None                T
# 239209          M     16261         16261     None                C
# 239210          M     16311         16311     None                T
# 239211          M     16385         16385     None                A
# 239212          M     16519         16519     None                T
#
#        Sample Allele Variation Type Gene Region Gene Symbol  \
# 0                  A            SNV      Exonic       OR4F5
# 1                  G            SNV      Exonic       OR4F5
# 2                  C            SNV      Exonic       OR4F5
# 3                  C            SNV      Exonic       OR4F5
# 4                  A            SNV      Exonic       OR4F5
# ...              ...            ...         ...         ...
# 239208             C            SNV        None        None
# 239209             T            SNV        None        None
# 239210             C            SNV        None        None
# 239211             G            SNV        None        None
# 239212             C            SNV        None        None
#
#                             Transcript ID  ...          Classification  \
# 0       ENST00000641515.2; NM_001005484.2  ...  Uncertain Significance
# 1       ENST00000641515.2; NM_001005484.2  ...                  Benign
# 2       ENST00000641515.2; NM_001005484.2  ...           Likely Benign
# 3       ENST00000641515.2; NM_001005484.2  ...  Uncertain Significance
# 4       ENST00000641515.2; NM_001005484.2  ...                  Benign
# ...                                   ...  ...                     ...
# 239208                               None  ...  Uncertain Significance
# 239209                               None  ...                  Benign
# 239210                               None  ...                  Benign
# 239211                               None  ...  Uncertain Significance
# 239212                               None  ...                  Benign
#
#        SIFT Score  CADD Score   dbSNP ID  HGMD  OMIM Gene OMIM Phenotype  \
# 0             NaN        < 10    2854682  None       None           None
# 1             NaN        < 10    2691305  None       None           None
# 2             NaN        < 10    2531266  None       None           None
# 3             NaN        < 10    2531267  None       None           None
# 4             NaN      33.000  776815449  None       None           None
# ...           ...         ...        ...   ...        ...            ...
# 239208        NaN        < 10  386420031  None       None           None
# 239209        NaN        < 10  138126107  None       None           None
# 239210        NaN        < 10   34799580  None       None           None
# 239211        NaN        < 10       None  None       None           None
# 239212        NaN        < 10    3937033  None       None           None
#
#        OMIM ID      n Lab_frequency
# 0         None   20.0      6.079027
# 1         None  113.0     34.346505
# 2         None   31.0      9.422492
# 3         None   22.0      6.686930
# 4         None   27.0      8.206687
# ...        ...    ...           ...
# 239208    None    7.0      1.772152
# 239209    None    9.0      2.278481
# 239210    None   13.0      3.291139
# 239211    None    2.0      0.506329
# 239212    None   36.0      9.113924
#
# [239213 rows x 45 columns]

# %%
data2.to_excel('MG24-5513-5515-MG25-0871-WGS-TRIO-hg38.xlsx',index=False)
